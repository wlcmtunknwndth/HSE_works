# %%
import pandas as pd

# %%
# !export PATH=/Library/TeX/texbin:$PATH
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df = pd.read_csv('bank_fin_1.csv', sep = ";")

# %%
display(df)
# df?
# Out:
#        age          job  marital  education default       balance housing  \
# 0       59       admin.  married  secondary      no   2 343,00 $      yes
# 1       56       admin.  married  secondary      no      45,00 $       no
# 2       41   technician  married  secondary      no   1 270,00 $      yes
# 3       55     services  married  secondary      no   2 476,00 $      yes
# 4       54       admin.  married   tertiary      no     184,00 $       no
# ...    ...          ...      ...        ...     ...           ...     ...
# 11157   33  blue-collar   single    primary      no       1,00 $      yes
# 11158   39     services  married  secondary      no     733,00 $       no
# 11159   32   technician   single  secondary      no      29,00 $       no
# 11160   43   technician  married  secondary      no         0  $       no
# 11161   34   technician  married  secondary      no         0  $       no
#
#       loan   contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
# Задание 1.
df.isna().sum()
# Out:
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance      25
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# deposit       0
# dtype: int64

# %%
# Задание 2
df[(df['deposit'] == 'yes') & (df['duration'] < df['duration'].mean())].shape
# Out:
# (2314, 17)

# %%
# Задание 3
def format(s):
    if type(s) is not str:
        s = str(s)
    s = s.strip().replace(',', '.').strip('$').replace(' ', '')
    # s = s.replace(',', '.')
    # s = s.strip()
    # print(s)
    return float(s)
print(format(" 29,00 $ "))
# df['balance']
# Out:
# 29.0

# %%
# df = df['balance'].apply(format)
df['balance'] = df['balance'].apply(format)
display(df)
round(df['balance'].mean(), 3)
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no   2343.0     yes   no
# 1       56       admin.  married  secondary      no     45.0      no   no
# 2       41   technician  married  secondary      no   1270.0     yes   no
# 3       55     services  married  secondary      no   2476.0     yes   no
# 4       54       admin.  married   tertiary      no    184.0      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no      1.0     yes   no
# 11158   39     services  married  secondary      no    733.0      no   no
# 11159   32   technician   single  secondary      no     29.0      no   no
# 11160   43   technician  married  secondary      no      0.0      no  yes
# 11161   34   technician  married  secondary      no      0.0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
# Задание 4
df['balance'] = df['balance'].fillna(df['balance'].median())
# df
print(df['balance'].isna().sum())
df['balance'].mean()
# Out:
# 0
# 1526.9360329690019

# %%
# Задание 5
df['deposit_new'] = df['deposit'].apply(lambda x: 1 if x == 'yes' else 0 )
display(df)
df['deposit_new'].mean()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no   2343.0     yes   no
# 1       56       admin.  married  secondary      no     45.0      no   no
# 2       41   technician  married  secondary      no   1270.0     yes   no
# 3       55     services  married  secondary      no   2476.0     yes   no
# 4       54       admin.  married   tertiary      no    184.0      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no      1.0     yes   no
# 11158   39     services  married  secondary      no    733.0      no   no
# 11159   32   technician   single  secondary      no     29.0      no   no
# 11160   43   technician  married  secondary      no      0.0      no  yes
# 11161   34   technician  married  secondary      no      0.0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
# Задание 6
df['age'].max()
# Out:
# 95

# %%
# Задание 7
df['duration'].min()
# Out:
# 2

# %%
# Задание 8
df[(df['deposit'] == 'yes') & (df['age'] > 50)].shape
# Out:
# (1313, 18)

# %%
# Задание 9
df[(df['job'] == 'student') & (df['marital'] == 'married')].shape
# Out:
# (15, 18)

# %%
# Задание 10
df[(df['marital'] == 'married') & (df['job'] == 'technician') & (df['loan'] == 'yes')].shape
# Out:
# (141, 18)
